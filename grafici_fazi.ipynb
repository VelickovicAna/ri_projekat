# %%
from matplotlib import pyplot as plt

# %%
plt.plot([0, 7, 13], [1, 1,0])
plt.plot([11, 15, 23, 26], [0, 1, 1, 0])
plt.plot([25, 30, 31], [0, 1, 1])
plt.title('vreme')
plt.legend(['hladno', 'umereno', 'toplo'])

# %%
plt.plot([0, 0.4, 0.5], [1, 1,0])
plt.plot([0.45, 0.55, 0.65, 0.7], [0, 1, 1, 0])
plt.plot([0.65, 1, 1.1], [0, 1, 1])
plt.title('formalnost')
plt.legend(['neformalno', 'umereno', 'formalno'])

# %%
plt.plot([0, 2, 3], [1, 1,0])
plt.plot([2, 4, 5, 6], [0, 1, 1, 0])
plt.plot([5,7, 8], [0, 1, 1])
plt.title('prodavnica')
plt.legend(['PS', 'SportVision', 'Springfild'])
