# %%
from matplotlib import pyplot as plt

# %%
plt.plot([0, 2, 7], [1, 1,0])
plt.plot([2, 3, 5, 7], [0, 1, 1, 0])
plt.plot([2,7, 8], [0, 1, 1])
plt.title('vreme')
plt.legend(['toplo', 'umereno', 'hladno'])

# %%
plt.plot([0, 3, 4], [1, 1,0])
plt.plot([3, 4, 6, 8], [0, 1, 1, 0])
plt.plot([4,8, 9], [0, 1, 1])
plt.title('formalnost')
plt.legend(['formalno', 'umereno', 'neformalno'])

# %%
plt.plot([0, 2, 3], [1, 1,0])
plt.plot([2, 4, 5, 6], [0, 1, 1, 0])
plt.plot([5,7, 8], [0, 1, 1])
plt.title('prodavnica')
plt.legend(['PS', 'SportVision', 'Springfild'])
